# %%
# numpy remainder? Couldn't finger out integer vs float for division.
import numpy as np
for i in range (14, 141, 1):
    if np.remainder(i,2) == 0 and np.remainder(i,7) > 0:
        print("Single")
    if np.remainder(i,7) == 0 and np.remainder(i,2) > 0:
        print("Cell")
    if np.remainder(i,2) == 0 and np.remainder(i,7) == 0:
        print("SingleCell")
    if np.remainder(i,2) > 0 and np.remainder(i,7) > 0: 
        print (i)
# Out:
# SingleCell
# 15
# Single
# 17
# Single
# 19
# Single
# Cell
# Single
# 23
# Single
# 25
# Single
# 27
# SingleCell
# 29
# Single
# 31
# Single
# 33
# Single
# Cell
# Single
# 37
# Single
# 39
# Single
# 41
# SingleCell
# 43
# Single
# 45
# Single
# 47
# Single
# Cell
# Single
# 51
# Single
# 53
# Single
# 55
# SingleCell
# 57
# Single
# 59
# Single
# 61
# Single
# Cell
# Single
# 65
# Single
# 67
# Single
# 69
# SingleCell
# 71
# Single
# 73
# Single
# 75
# Single
# Cell
# Single
# 79
# Single
# 81
# Single
# 83
# SingleCell
# 85
# Single
# 87
# Single
# 89
# Single
# Cell
# Single
# 93
# Single
# 95
# Single
# 97
# SingleCell
# 99
# Single
# 101
# Single
# 103
# Single
# Cell
# Single
# 107
# Single
# 109
# Single
# 111
# SingleCell
# 113
# Single
# 115
# Single
# 117
# Single
# Cell
# Single
# 121
# Single
# 123
# Single
# 125
# SingleCell
# 127
# Single
# 129
# Single
# 131
# Single
# Cell
# Single
# 135
# Single
# 137
# Single
# 139
# SingleCell
